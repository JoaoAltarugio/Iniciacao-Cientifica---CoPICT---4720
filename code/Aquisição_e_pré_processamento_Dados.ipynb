# %%
# !pip install yfinance
import yfinance as yf

# %%
import yfinance as yf

PETR3 = yf.download('PETR3.SA', auto_adjust=False)
PETR4 = yf.download('PETR4.SA', auto_adjust=False)
VALE3 = yf.download('VALE3.SA', auto_adjust=False)
ITUB3 = yf.download('ITUB3.SA', auto_adjust=False)
ITUB4 = yf.download('ITUB4.SA', auto_adjust=False)
BBDC3 = yf.download('BBDC3.SA', auto_adjust=False)
BBDC4 = yf.download('BBDC4.SA', auto_adjust=False)
B3SA3 = yf.download('B3SA3.SA', auto_adjust=False)
ABEV3 = yf.download('ABEV3.SA', auto_adjust=False)
BOVA11 = yf.download('BOVA11.SA', auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ##Visualização

# %%
BOVA11['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##Verificação de NAN

# %%
PETR3_NULL = PETR3.isna().sum()
PETR4_NULL = PETR4.isna().sum()
VALE3_NULL = VALE3.isna().sum()
ITUB3_NULL = ITUB3.isna().sum()
ITUB4_NULL = ITUB4.isna().sum()
BBDC3_NULL = BBDC3.isna().sum()
BBDC4_NULL = BBDC4.isna().sum()
B3SA3_NULL = B3SA3.isna().sum()
ABEV3_NULL = ABEV3.isna().sum()
BOVA11_NULL = BOVA11.isna().sum()
print("PETR3_NULL:\n", PETR3_NULL, "\n")
print("PETR4_NULL:\n", PETR4_NULL, "\n")
print("VALE3_NULL:\n", VALE3_NULL, "\n")
print("ITUB3_NULL:\n", ITUB3_NULL, "\n")
print("ITUB4_NULL:\n", ITUB4_NULL, "\n")
print("BBDC3_NULL:\n", BBDC3_NULL, "\n")
print("BBDC4_NULL:\n", BBDC4_NULL, "\n")
print("B3SA3_NULL:\n", B3SA3_NULL, "\n")
print("ABEV3_NULL:\n", ABEV3_NULL, "\n")
print("BOVA11_NULL:\n", BOVA11_NULL, "\n")
# Out:
# PETR3_NULL:
#  Price      Ticker
# Adj Close  PETR3.SA    0
# Close      PETR3.SA    0
# High       PETR3.SA    0
# Low        PETR3.SA    0
# Open       PETR3.SA    0
# Volume     PETR3.SA    0
# dtype: int64
#
# PETR4_NULL:
#  Price      Ticker
# Adj Close  PETR4.SA    0
# Close      PETR4.SA    0
# High       PETR4.SA    0
# Low        PETR4.SA    0
# Open       PETR4.SA    0
# Volume     PETR4.SA    0
# dtype: int64
#
# VALE3_NULL:
#  Price      Ticker
# Adj Close  VALE3.SA    0
# Close      VALE3.SA    0
# High       VALE3.SA    0
# Low        VALE3.SA    0
# Open       VALE3.SA    0
# Volume     VALE3.SA    0
# dtype: int64
#
# ITUB3_NULL:
#  Price      Ticker
# Adj Close  ITUB3.SA    0
# Close      ITUB3.SA    0
# High       ITUB3.SA    0
# Low        ITUB3.SA    0
# Open       ITUB3.SA    0
# Volume     ITUB3.SA    0
# dtype: int64
#
# ITUB4_NULL:
#  Price      Ticker
# Adj Close  ITUB4.SA    0
# Close      ITUB4.SA    0
# High       ITUB4.SA    0
# Low        ITUB4.SA    0
# ...

# %% [markdown]
# ##Queremos apenas o close com a data em dias

# %% [markdown]
# ###BOVA11

# %%
BOVA11.columns = BOVA11.columns.droplevel(level=1)
BOVA11.index = BOVA11.index.strftime('%y/%m/%d')
#BOVA11.reset_index(drop=True, inplace=True)
BOVA11 = BOVA11.rename_axis(None, axis=1)
#BOVA11 = BOVA11.drop(columns=['Close', 'High', 'Low', 'Open'])
BOVA11.head()
# Out:
#           Adj Close      Close       High        Low       Open  Volume
# Date
# 09/04/17  45.849998  45.849998  45.980000  45.599998  45.700001  274700
# 09/04/20  44.419998  44.419998  44.900002  44.070000  44.790001  265800
# 09/04/22  44.990002  44.990002  45.240002  44.509998  44.610001  234800
# 09/04/23  45.900002  45.900002  45.900002  44.860001  45.189999  305900
# 09/04/24  46.689999  46.689999  46.849998  46.099998  46.169998  325600

# %% [markdown]
# output_file = 'BOVA11.csv'
# BOVA11.to_csv(output_file, index=True)
#
# try:
#     from google.colab import files
#     files.download(output_file)
# except ImportError:
#     print(f"O arquivo '{output_file}' foi salvo no diretório atual.")

# %% [markdown]
# #Outros Assets

# %%
ativos = [PETR3, PETR4, VALE3, ITUB3, ITUB4, BBDC3, BBDC4, B3SA3, ABEV3]

for i, df in enumerate(ativos):
    df.columns = df.columns.droplevel(level=1)
    df.index = df.index.strftime('%y/%m/%d')
    df.reset_index(drop=True, inplace=True)
    df.rename_axis(None, axis=1, inplace=True)
    df.drop(columns=['Adj Close', 'High', 'Low', 'Open', 'Volume'], inplace=True)

# %%
PETR4
# Out:
#           Close
# 0      5.875000
# 1      5.550000
# 2      5.494000
# 3      5.475000
# 4      5.500000
# ...         ...
# 6355  30.400000
# 6356  30.559999
# 6357  29.990000
# 6358  30.809999
# 6359  29.990000
#
# [6360 rows x 1 columns]

# %%
# Lista de DataFrames e seus nomes correspondentes
ativos = {
    'PETR3': PETR3,
    'PETR4': PETR4,
    'VALE3': VALE3,
    'ITUB3': ITUB3,
    'ITUB4': ITUB4,
    'BBDC3': BBDC3,
    'BBDC4': BBDC4,
    'B3SA3': B3SA3,
    'ABEV3': ABEV3,
    'BOVA11': BOVA11
}

from google.colab import files

for nome, df in ativos.items():
    output_file = f'{nome}.csv'
    df.to_csv(output_file, index=True)

    try:
        files.download(output_file)
    except ImportError:
        print(f"O arquivo '{output_file}' foi salvo no diretório atual.")
